# %%
import webbrowser
webbrowser.open('https://github.com/BIGBALLON/cifar-10-cnn/blob/master/5_Wide_Residual_Network/Wide_ResNet_keras.py', new=2)
# Out:
# True

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

from keras.preprocessing.image import ImageDataGenerator
from keras.layers import BatchNormalization
from keras.layers import Conv2D, Dense, Input, add, Activation, Flatten, AveragePooling2D
from keras.callbacks import LearningRateScheduler, TensorBoard
from keras.regularizers import l2
from keras import optimizers
from keras.models import Model
from keras import backend

# %%
DEPTH              = 28
WIDE               = 10
IN_FILTERS         = 16

CLASS_NUM          = 10
IMG_ROWS, IMG_COLS = 32, 32
IMG_CHANNELS       = 3

BATCH_SIZE         = 128
EPOCHS             = 200
ITERATIONS         = 50000 // BATCH_SIZE + 1
WEIGHT_DECAY       = 0.0005
LOG_FILE_PATH      = './w_resnet/'

# %%
# set GPU memory 
# if('tensorflow' == backend.backend()):
#     config = tf.ConfigProto()
#     config.gpu_options.allow_growth = True
#     sess = tf.Session(config=config)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 # set GPU memory
#       2 if('tensorflow' == backend.backend()):
# ----> 3     config = tf.ConfigProto()
#       4     config.gpu_options.allow_growth = True
#       5     sess = tf.Session(config=config)
#
# AttributeError: module 'tensorflow' has no attribute 'ConfigProto'

# %%
def scheduler(epoch):
    if epoch < 60:
        return 0.1
    if epoch < 120:
        return 0.02
    if epoch < 160:
        return 0.004
    return 0.0008

# %%
def wide_residual_network(img_input,classes_num,depth,k):
    print('Wide-Resnet %dx%d' %(depth, k))
    n_filters  = [16, 16*k, 32*k, 64*k]
    n_stack    = (depth - 4) // 6

    def conv3x3(x,filters):
        return Conv2D(filters=filters, kernel_size=(3,3), strides=(1,1), padding='same',
        kernel_initializer='he_normal',
        kernel_regularizer=l2(WEIGHT_DECAY),
        use_bias=False)(x)

    def bn_relu(x):
        x = BatchNormalization(momentum=0.9, epsilon=1e-5)(x)
        x = Activation('relu')(x)
        return x

    def residual_block(x,out_filters,increase=False):
        global IN_FILTERS
        stride = (1,1)
        if increase:
            stride = (2,2)
            
        o1 = bn_relu(x)
        
        conv_1 = Conv2D(out_filters,
            kernel_size=(3,3),strides=stride,padding='same',
            kernel_initializer='he_normal',
            kernel_regularizer=l2(WEIGHT_DECAY),
            use_bias=False)(o1)

        o2 = bn_relu(conv_1)
        
        conv_2 = Conv2D(out_filters, 
            kernel_size=(3,3), strides=(1,1), padding='same',
            kernel_initializer='he_normal',
            kernel_regularizer=l2(WEIGHT_DECAY),
            use_bias=False)(o2)
        if increase or IN_FILTERS != out_filters:
            proj = Conv2D(out_filters,
                                kernel_size=(1,1),strides=stride,padding='same',
                                kernel_initializer='he_normal',
                                kernel_regularizer=l2(WEIGHT_DECAY),
                                use_bias=False)(o1)
            block = add([conv_2, proj])
        else:
            block = add([conv_2,x])
        return block

    def wide_residual_layer(x,out_filters,increase=False):
        global IN_FILTERS
        x = residual_block(x,out_filters,increase)
        IN_FILTERS = out_filters
        for _ in range(1,int(n_stack)):
            x = residual_block(x,out_filters)
        return x


    x = conv3x3(img_input,n_filters[0])
    x = wide_residual_layer(x,n_filters[1])
    x = wide_residual_layer(x,n_filters[2],increase=True)
    x = wide_residual_layer(x,n_filters[3],increase=True)
    x = BatchNormalization(momentum=0.9, epsilon=1e-5)(x)
    x = Activation('relu')(x)
    x = AveragePooling2D((8,8))(x)
    x = Flatten()(x)
    x = Dense(classes_num,
        activation='softmax',
        kernel_initializer='he_normal',
        kernel_regularizer=l2(WEIGHT_DECAY),
        use_bias=False)(x)
    return x

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 38s 0us/step

# %%
y_train = to_categorical(y_train, CLASS_NUM)
y_test = to_categorical(y_test, CLASS_NUM)

# color preprocessing
x_train, x_test = x_train.astype('float32') / 255, x_test.astype('float32') / 255

# build network
img_input = Input(shape=(IMG_ROWS,IMG_COLS,IMG_CHANNELS))
output = wide_residual_network(img_input,CLASS_NUM,DEPTH,WIDE)
resnet = Model(img_input, output)
print(resnet.summary())
# set optimizer
sgd = optimizers.SGD(lr=.1, momentum=0.9, nesterov=True)
resnet.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# set callback
tb_cb = TensorBoard(log_dir=LOG_FILE_PATH, histogram_freq=0)
change_lr = LearningRateScheduler(scheduler)
cbks = [change_lr,tb_cb]

# set data augmentation
print('Using real-time data augmentation.')
datagen = ImageDataGenerator(horizontal_flip=True,
        width_shift_range=0.125,height_shift_range=0.125,fill_mode='reflect')

datagen.fit(x_train)

# start training
resnet.fit_generator(datagen.flow(x_train, y_train,batch_size=BATCH_SIZE),
                    steps_per_epoch=ITERATIONS,
                    epochs=EPOCHS,
                    callbacks=cbks,
                    validation_data=(x_test, y_test))
resnet.save('wresnet.h5')
# Out:
# Wide-Resnet 28x10
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 16)   432         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 16)  64          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 16)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 160)  23040       ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 160)  640        ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 160)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 160)  230400      ['activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 160)  2560        ['activation[0][0]']
#
#  add (Add)                      (None, 32, 32, 160)  0           ['conv2d_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 160)  640        ['add[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 32, 160)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 160)  230400      ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 160)  640        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 160)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 160)  230400      ['activation_3[0][0]']
#
#  add_1 (Add)                    (None, 32, 32, 160)  0           ['conv2d_5[0][0]',
#                                                                   'add[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 160)  640        ['add_1[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 160)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 160)  230400      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 160)  640        ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 160)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 160)  230400      ['activation_5[0][0]']
#
#  add_2 (Add)                    (None, 32, 32, 160)  0           ['conv2d_7[0][0]',
#                                                                   'add_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 160)  640        ['add_2[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 160)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 160)  230400      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 160)  640        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 160)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 160)  230400      ['activation_7[0][0]']
#
#  add_3 (Add)                    (None, 32, 32, 160)  0           ['conv2d_9[0][0]',
#                                                                   'add_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 160)  640        ['add_3[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 32, 32, 160)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 320)  460800      ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 320)  1280       ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 16, 16, 320)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 320)  921600      ['activation_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 320)  51200       ['activation_8[0][0]']
#
#  add_4 (Add)                    (None, 16, 16, 320)  0           ['conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 320)  1280       ['add_4[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 320)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 320)  921600      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 320)  1280       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 16, 16, 320)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 320)  921600      ['activation_11[0][0]']
#
#  add_5 (Add)                    (None, 16, 16, 320)  0           ['conv2d_14[0][0]',
#                                                                   'add_4[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 320)  1280       ['add_5[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 16, 16, 320)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 320)  921600      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 320)  1280       ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 16, 16, 320)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 320)  921600      ['activation_13[0][0]']
#
#  add_6 (Add)                    (None, 16, 16, 320)  0           ['conv2d_16[0][0]',
#                                                                   'add_5[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 320)  1280       ['add_6[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 16, 16, 320)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 320)  921600      ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 320)  1280       ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 16, 16, 320)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 320)  921600      ['activation_15[0][0]']
#
#  add_7 (Add)                    (None, 16, 16, 320)  0           ['conv2d_18[0][0]',
#                                                                   'add_6[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 320)  1280       ['add_7[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 16, 16, 320)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 8, 8, 640)    1843200     ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 8, 8, 640)   2560        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 8, 8, 640)    0           ['batch_normalization_17[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 8, 8, 640)    3686400     ['activation_17[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 8, 8, 640)    204800      ['activation_16[0][0]']
#
#  add_8 (Add)                    (None, 8, 8, 640)    0           ['conv2d_20[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 8, 8, 640)   2560        ['add_8[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 8, 8, 640)    0           ['batch_normalization_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 640)    3686400     ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 8, 8, 640)   2560        ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 8, 8, 640)    0           ['batch_normalization_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 8, 8, 640)    3686400     ['activation_19[0][0]']
#
#  add_9 (Add)                    (None, 8, 8, 640)    0           ['conv2d_23[0][0]',
#                                                                   'add_8[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 8, 8, 640)   2560        ['add_9[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 8, 8, 640)    0           ['batch_normalization_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 8, 8, 640)    3686400     ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 640)   2560        ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 8, 8, 640)    0           ['batch_normalization_21[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 8, 8, 640)    3686400     ['activation_21[0][0]']
#
#  add_10 (Add)                   (None, 8, 8, 640)    0           ['conv2d_25[0][0]',
#                                                                   'add_9[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 8, 8, 640)   2560        ['add_10[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 8, 8, 640)    0           ['batch_normalization_22[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 8, 8, 640)    3686400     ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 8, 8, 640)   2560        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 8, 8, 640)    0           ['batch_normalization_23[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 8, 8, 640)    3686400     ['activation_23[0][0]']
#
#  add_11 (Add)                   (None, 8, 8, 640)    0           ['conv2d_27[0][0]',
#                                                                   'add_10[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 640)   2560        ['add_11[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 8, 8, 640)    0           ['batch_normalization_24[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 640)   0           ['activation_24[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 640)          0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 10)           6400        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 36,497,136
# Trainable params: 36,479,184
# Non-trainable params: 17,952
# __________________________________________________________________________________________________
# None
# Using real-time data augmentation.
# c:\Users\FIMILAK\AppData\Local\miniconda3\envs\studienarbeit_env\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# C:\Users\FIMILAK\AppData\Local\Temp\ipykernel_2464\1031515706.py:29: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   resnet.fit_generator(datagen.flow(x_train, y_train,batch_size=BATCH_SIZE),
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
